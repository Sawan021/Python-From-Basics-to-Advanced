# %% [markdown]
# ## PANDAS : Data Manipulation

# %%
import pandas as pd

# %%
titanic_train = pd.read_csv('titanic.csv')

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# There are a lot of new of new librarires in the market better than Pandas but we donot adopt them at industry level because they have to be SCABALE AND STABLE to handle that much bulk of data.

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic_train)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#it is to be noted that series in pandas is almost similar to list but not same
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
#extracting data from a series

dy=titanic_train.dtypes

# %%
dy['Pclass']
# Out:
# dtype('int64')

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy[0]
# Out:
# dtype('int64')

# %%
dy[0:4]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# dtype: object

# %% [markdown]
# IN series we call the object by its index name or its default index name.Whereas in lists we define it by using only lists index.

# %%
dy[0:100:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Age'][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
#printing in reverse direction
titanic_train['Age'][::-1]
# Out:
# 890    32.0
# 889    26.0
# 888     NaN
# 887    19.0
# 886    27.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_train['Age'][-1]

#negative indexes doesnt exit. Lists mai it exists.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-7e729c784310> in <module>
# ----> 1 titanic_train['Age'][-1]
#       2
#       3 #negative indexes doesnt exit. Lists mai it exists.
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ...

# %%
list(titanic_train['Age'][::2])
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan,
#  16.0,
#  nan,
#  44.0,
#  26.0,
#  1.0,
#  nan,
#  nan,
#  61.0,
#  1.0,
#  56.0,
#  nan,
#  30.0,
#  nan,
#  9.0,
#  4.0,
#  nan,
#  40.0,
#  32.0,
#  19.0,
#  44.0,
#  nan,
#  nan,
#  28.0,
#  34.0,
#  18.0,
#  32.0,
#  16.0,
#  24.0,
#  22.0,
#  nan,
#  27.0,
#  32.0,
#  16.0,
#  51.0,
#  38.0,
#  19.0,
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#here we will get the description of statistical data of numeircal data types
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Getting description about CATEGORICAL DATA

#step-1 returns datatypes : titanic_train.dtypes
#step-2 selects the datatype: titanic_train.dtypes=='object'
#step-3
titanic_train.dtypes[titanic_train.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# step-4 accessing all the colum,ns having the datatypes as object

titanic_train[titanic_train.dtypes[titanic_train.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train_cat=titanic_train[titanic_train.dtypes[titanic_train.dtypes=='object'].index]
titanic_train_cat.describe()
# Out:
#                          Name   Sex    Ticket        Cabin Embarked
# count                     891   891       891          204      889
# unique                    891     2       681          147        3
# top     Beesley, Mr. Lawrence  male  CA. 2343  C23 C25 C27        S
# freq                        1   577         7            4      644

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#whenever multiple columns are passed they are passed as a list
# this is wromng titanic_train['Name','Fare']
titanic_train[['Name','Fare']]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas  13.0000
# 887                       Graham, Miss. Margaret Edith  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889                              Behr, Mr. Karl Howell  30.0000
# 890                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 2 columns]

# %%
# Anything passed in form of list will give us DATAFRAME
type(titanic_train[['Name','Fare']])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
import numpy as np

# %%
# np.where gives a list of complete indexes, where null values of each columns is there
np.where(titanic_train['Age'].isnull()==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train_age_null =np.where(titanic_train['Age'].isnull()==True)

# %%
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train[['Name','Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %% [markdown]
# iloc() helps us to select a specific row or column from the data set. Using the iloc() function in python, we can easily retrieve any particular value from a row or column using index

# %%
# Reading the data out of a row
# this can be achieved by using iloc

titanic_train.iloc[titanic_train_age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# iloc is integer location

titanic_train.iloc[6]
# Out:
# PassengerId                          7
# Survived                             0
# Pclass                               1
# Name           McCarthy, Mr. Timothy J
# Sex                               male
# Age                                 54
# SibSp                                0
# Parch                                0
# Ticket                           17463
# Fare                           51.8625
# Cabin                              E46
# Embarked                             S
# Name: 6, dtype: object

# %% [markdown]
# Irrespective of one columns or row it woll return data as a series

# %%
type(titanic_train.iloc[6])
# Out:
# pandas.core.series.Series

# %%
titanic_train.iloc[[1,2,3,4,5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
# Give a name who has paid highest fare
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train.iloc[[1,2,3,5,67]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 5             6         0       3
# 67           68         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 67                           Crease, Mr. Ernest James    male  19.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 5       0            330877   8.4583   NaN        Q
# ...

# %%
# Person age whose cabin value is NaN
titanic_train[['Age','Cabin']][titanic_train.Cabin.isnull()==True]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
titanic_train.iloc[np.where(titanic_train['Cabin'].isnull()==True)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic_train.iloc[np.where(titanic_train['Cabin'].isnull()==True)][['Name','Cabin']]
# Out:
#                                          Name Cabin
# 0                     Braund, Mr. Owen Harris   NaN
# 2                      Heikkinen, Miss. Laina   NaN
# 4                    Allen, Mr. William Henry   NaN
# 5                            Moran, Mr. James   NaN
# 7              Palsson, Master. Gosta Leonard   NaN
# ..                                        ...   ...
# 884                    Sutehall, Mr. Henry Jr   NaN
# 885      Rice, Mrs. William (Margaret Norton)   NaN
# 886                     Montvila, Rev. Juozas   NaN
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                       Dooley, Mr. Patrick   NaN
#
# [687 rows x 2 columns]

# %%
# Name of passenger who has survived that is value=1

titanic_train.Name[(titanic_train.Survived == 1) & (titanic_train.Sex == "male")]
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
titanic_train['new_col']="sawanNC"
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d={'key':'Sawa',"title":"kumar","mail_id":"sawa@gmail.com"}

# %%
pd.DataFrame(d,index=['key','title','mail_id'])
# Out:
#           key  title         mail_id
# key      Sawa  kumar  sawa@gmail.com
# title    Sawa  kumar  sawa@gmail.com
# mail_id  Sawa  kumar  sawa@gmail.com

# %%
pd.Series(d)
# Out:
# key                  Sawa
# title               kumar
# mail_id    sawa@gmail.com
# dtype: object

# %%
arr=np.random.randn(3,4)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  0.031040 -1.048965  0.089197 -0.413156
# 1  0.473401 -1.311544  1.653022  1.536086
# 2  0.755638  0.877373 -1.125841 -0.691812

# %%
ser= pd.Series(np.array([4,5,6,7,8]),index=['a','b','sawa',"Kumar",'c'])
ser
# Out:
# a        4
# b        5
# sawa     6
# Kumar    7
# c        8
# dtype: int32

# %%
ser['sawa']
# Out:
# 6

# %%
ser.iloc[0]
# Out:
# 4

# %%
# passing the name index
ser.loc['sawa']
# Out:
# 6

# %%
ser1= pd.Series(np.array([4,5,6,7,8]),index=[45,56,67,78,43])
ser1
# Out:
# 45    4
# 56    5
# 67    6
# 78    7
# 43    8
# dtype: int32

# %%
ser1.iloc[51]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-280a5a11aba7> in <module>
# ----> 1 ser1.iloc[51]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
# ...

# %% [markdown]
# index is not default however it is a integer
#
# iloc: it takes integer indexes and only default indexes, not given by me
#
# loc: it taked named indexes

# %%
pd.DataFrame(np.random.randint(3,6,(4,5)))
# Out:
#    0  1  2  3  4
# 0  4  3  4  3  5
# 1  4  3  4  4  5
# 2  3  4  5  5  4
# 3  3  5  5  3  4

# %%
df=pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])
df
# Out:
#    x  y  z  u  v
# a  4  5  3  5  4
# b  4  4  5  3  4
# c  4  5  4  4  4
# d  5  5  3  3  5

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  5  3
# d  4  5

# %%
df['new']=df['x']+df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  4  5  3  5  4    9
# b  4  4  5  3  4    8
# c  4  5  4  4  4    9
# d  5  5  3  3  5   10

# %%
# Deleting the rows and columns

df.drop('x')
# here it is howing error because by default axis=0 for a row and axis=1 for a column
#hence we need to change the axis as x is not in rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-c6bac7bccdd6> in <module>
#       1 # Deleting the rows and columns
#       2
# ----> 3 df.drop('x')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df.drop('x',axis=1)
# Out:
#    y  z  u  v  new
# a  5  3  5  4    9
# b  4  5  3  4    8
# c  5  4  4  4    9
# d  5  3  3  5   10

# %%
df
#it will not drop permanently until unless we have a reassigned it
# Out:
#    x  y  z  u  v  new
# a  4  5  3  5  4    9
# b  4  4  5  3  4    8
# c  4  5  4  4  4    9
# d  5  5  3  3  5   10

# %%
df.drop('x',axis=1,inplace=True)
#inplace we maek sure it is deleted permanently

# %%
df
# Out:
#    y  z  u  v  new
# a  5  3  5  4    9
# b  4  5  3  4    8
# c  5  4  4  4    9
# d  5  3  3  5   10

# %%
df.drop('c',inplace=True)

# %%
df
# Out:
#    y  z  u  v  new
# a  5  3  5  4    9
# b  4  5  3  4    8
# d  5  3  3  5   10

# %%
pd.DataFrame(np.random.rand(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])
# Out:
#           x         y         z         u         v
# a  0.841925  0.108507  0.217107  0.761664  0.702757
# b  0.175426  0.630749  0.144234  0.681144  0.616985
# c  0.189503  0.132399  0.151821  0.113426  0.752246
# d  0.082485  0.455097  0.664682  0.821694  0.098423

# %%
np.random.seed(23)
df=pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
df[df<0]
#this is okay but it doesnt have only neagitve value
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
# extarct column name and row name for negative values in (row, column)

c = df.values[df.values<0]
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] in c:
            print(i,j)
# Out:
# x b
# x c
# x d
# y b
# z a
# z b
# u b
# u d
# v c
# v d

# %%
#alternate solution 

l = df.values[df<0]
for c in df.columns:
    for v in df.index:
        if df[c][v] in l:
            print(c,v,df[c][v])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
import pandas as pd

# %%
import numpy as np

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sawan" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0  sawan   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# requires that many non-NA values
#it will check how many non-zero values we in row are present
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0  sawan   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
#thresh=1 perform same operation, checks atleast 1 non-zero value
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0  sawan   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
# it is expecting atleast 2 non-NA values, agr 2 se kum non-NA values hue toh it will drop that row
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0  sawan   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
# Same operation can be performed column wise by putting axis=0
df.dropna(thresh=3, axis=1)

#or,  df.dropna(axis=1,thresh=3)
# Out:
#    key1   key2
# 0   1.0  sawan
# 1   2.0  kumar
# 2   3.0    NaN
# 3   4.0      5
# 4   NaN      6

# %%
# Will fill NaN values with given number
df.fillna(9876)
# Out:
#      key1   key2    key3
# 0     1.0  sawan  9876.0
# 1     2.0  kumar  9876.0
# 2     3.0   9876  9876.0
# 3     4.0      5     3.0
# 4  9876.0      6     8.0

# %%
df.fillna(value=df['key1'].mean())

# Note that these mean, median, mode are not be filled in this rows/columns
# ML algo's are often used to fill these NaN values
# this operation is called imputation
# Out:
#    key1   key2  key3
# 0   1.0  sawan   2.5
# 1   2.0  kumar   2.5
# 2   3.0    2.5   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
d1 = {'name' :['skm' , 'visali' , 'umang', 'vishal' ,'umang'],"mail_id" :["skm@gmail.com", "visali@gmail.com",'umang@gmail.com','vishal@gmail.com','umang@gmail.com'],
     'salary' :[100,200,500,200,500]}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  salary
# 0     skm     skm@gmail.com     100
# 1  visali  visali@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby('name').mean()
# Out:
#         salary
# name
# skm        100
# umang      500
# visali     200
# vishal     200

# %%
df.groupby('mail_id').mean()
# Out:
#                   salary
# mail_id
# skm@gmail.com        100
# umang@gmail.com      500
# visali@gmail.com     200
# vishal@gmail.com     200

# %%
df.groupby('mail_id').sum()
# Out:
#                   salary
# mail_id
# skm@gmail.com        100
# umang@gmail.com     1000
# visali@gmail.com     200
# vishal@gmail.com     200

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# skm@gmail.com       1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# visali@gmail.com    1.0  200.0  NaN  200.0  200.0  200.0  200.0  200.0
# vishal@gmail.com    1.0  200.0  NaN  200.0  200.0  200.0  200.0  200.0

# %%
# extracting detials of umang

df.groupby('mail_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com'][1]
# Out:
# 500.0

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']['mean']
# Out:
# 500.0

# %%
# converting row into column & column into row

df.groupby('mail_id').describe().T
# Out:
# mail_id       skm@gmail.com  umang@gmail.com  visali@gmail.com  \
# salary count            1.0              2.0               1.0
#        mean           100.0            500.0             200.0
#        std              NaN              0.0               NaN
#        min            100.0            500.0             200.0
#        25%            100.0            500.0             200.0
#        50%            100.0            500.0             200.0
#        75%            100.0            500.0             200.0
#        max            100.0            500.0             200.0
#
# mail_id       vishal@gmail.com
# salary count               1.0
#        mean              200.0
#        std                 NaN
#        min               200.0
#        25%               200.0
#        50%               200.0
#        75%               200.0
#        max               200.0

# %%
arr1=np.random.randn(3,4)

# %%
arr2=np.random.randn(3,4)

# %%
arr3=np.random.randn(3,4)

# %%
df1=pd.DataFrame(arr1,columns=["A","B","C","D"],index=[0,1,2])

# %%
df2=df1=pd.DataFrame(arr2,columns=["A","B","C","D"],index=[0,1,2])

# %%
df3=df1=pd.DataFrame(arr3,columns=["A","B","C","D"],index=[0,1,2])

# %%
df1
# Out:
#           A         B         C         D
# 0  1.443541  0.526591 -1.313695 -2.203113
# 1 -0.918871  0.780061  0.073901 -0.218782
# 2  0.382265  0.472894  1.920814  0.385505

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.266887 -1.192895 -0.525938 -1.172666
# 1 -0.336518  0.283154 -0.835766 -0.954650
# 2 -0.595011  0.598454 -1.014368 -2.043888

# %%
df3
# Out:
#           A         B         C         D
# 0  1.443541  0.526591 -1.313695 -2.203113
# 1 -0.918871  0.780061  0.073901 -0.218782
# 2  0.382265  0.472894  1.920814  0.385505

# %%
df4=pd.concat([df1,df2,df3])
#by default row-wise concatination

# %%
df4
# Out:
#           A         B         C         D
# 0  1.443541  0.526591 -1.313695 -2.203113
# 1 -0.918871  0.780061  0.073901 -0.218782
# 2  0.382265  0.472894  1.920814  0.385505
# 0 -0.266887 -1.192895 -0.525938 -1.172666
# 1 -0.336518  0.283154 -0.835766 -0.954650
# 2 -0.595011  0.598454 -1.014368 -2.043888
# 0  1.443541  0.526591 -1.313695 -2.203113
# 1 -0.918871  0.780061  0.073901 -0.218782
# 2  0.382265  0.472894  1.920814  0.385505

# %%
df5=pd.concat([df1,df2,df3],axis=1)
df5
#by default column-wise concatination
# Out:
#           A         B         C         D         A         B         C  \
# 0  1.443541  0.526591 -1.313695 -2.203113 -0.266887 -1.192895 -0.525938
# 1 -0.918871  0.780061  0.073901 -0.218782 -0.336518  0.283154 -0.835766
# 2  0.382265  0.472894  1.920814  0.385505 -0.595011  0.598454 -1.014368
#
#           D         A         B         C         D
# 0 -1.172666  1.443541  0.526591 -1.313695 -2.203113
# 1 -0.954650 -0.918871  0.780061  0.073901 -0.218782
# 2 -2.043888  0.382265  0.472894  1.920814  0.385505

# %%
#we need to extract default indexes

df4.iloc[0]
# Out:
# A    1.443541
# B    0.526591
# C   -1.313695
# D   -2.203113
# Name: 0, dtype: float64

# %%
df5['A']
# Out:
#           A         A         A
# 0  1.443541 -0.266887  1.443541
# 1 -0.918871 -0.336518 -0.918871
# 2  0.382265 -0.595011  0.382265

# %%
df5.iloc[:,4]
# Out:
# 0   -0.266887
# 1   -0.336518
# 2   -0.595011
# Name: A, dtype: float64

# %%
df1
# Out:
#           A         B         C         D
# 0  1.443541  0.526591 -1.313695 -2.203113
# 1 -0.918871  0.780061  0.073901 -0.218782
# 2  0.382265  0.472894  1.920814  0.385505

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.266887 -1.192895 -0.525938 -1.172666
# 1 -0.336518  0.283154 -0.835766 -0.954650
# 2 -0.595011  0.598454 -1.014368 -2.043888

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)

np.random.seed(23)
arr2 = np.random.randn(3,4)

df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22)
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22,on="A")
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %% [markdown]
# Here it is to be noted that, column values are merged for both df11 ,df22. where as the values B_x, C_x are from df11 adn B_y,C_y are from df22.

# %%
df1 = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(df1,df2, on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %% [markdown]
# This is a merge operation similar to intersetion of sets or "inner merge"

# %%
pd.merge(df1,df2, on='key', how='left')
#merging the dataFrame from left i.e df1
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(df1,df2, on='key', how='right')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
pd.merge(df1,df2, on='key', how='outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2,on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %% [markdown]
# Here join uses index of the columns and join is performed based on index of columns. whereas in merge it is performed on basis of columns.

# %%
df1.join(df2,how='right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %%
df1.join(df2,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# #### Some commonly used functions

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2022-09-06',periods=10),columns=['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new column']=df['c']+df['d']
df
# Out:
#                    a         b         c         d       new  new column
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913

# %%
df['new_col_sq_d']=df['d'].apply(lambda x:x**2)
df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d
# 2022-09-06      5.490876
# 2022-09-07      0.957425
# 2022-09-08      0.243454
# 2022-09-09      0.060376
# 2022-09-10      0.165135
# ...

# %%
df['new_col_log_d']=df['d'].apply(lambda x:np.log(x))
df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d  new_col_log_d
# 2022-09-06      5.490876            NaN
# 2022-09-07      0.957425            NaN
# 2022-09-08      0.243454            NaN
# ...

# %%
def test(x):
    if(x<0):
        return x
    else:
        return np.log(x)

# %%
df['new_col_dq_log_d']=df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d  new_col_log_d  new_col_dq_log_d
# 2022-09-06      5.490876            NaN         -2.343262
# ...

# %%
def test1(x):
    if x<0:
        return 1
    else:
        return 0

# %%
df['new_a']=df['a'].apply(test1)
df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d  new_col_log_d  new_col_dq_log_d  new_a
# 2022-09-06      5.490876            NaN         -2.343262      0
# ...

# %%
df.sort_values(by='b')
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
#
#             new_col_sq_d  new_col_log_d  new_col_dq_log_d  new_a
# 2022-09-11      1.776298       0.287266          0.287266      1
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2022-09-06', '2022-09-07', '2022-09-08', '2022-09-09',
#                '2022-09-10', '2022-09-11', '2022-09-12', '2022-09-13',
#                '2022-09-14', '2022-09-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df['new_date']=df.index

# %%
df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d  new_col_log_d  new_col_dq_log_d  new_a   new_date
# 2022-09-06      5.490876            NaN         -2.343262      0 2022-09-06
# ...

# %%
df.dtypes
# Out:
# a                          float64
# b                          float64
# c                          float64
# d                          float64
# new                        float64
# new column                 float64
# new_col_sq_d               float64
# new_col_log_d              float64
# new_col_dq_log_d           float64
# new_a                        int64
# new_date            datetime64[ns]
# dtype: object

# %%
#separating data separation based on year, month, date separately

df['day']=df.index.day
df['month']=df.index.month
df['year']=df.index.year

df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d  new_col_log_d  new_col_dq_log_d  new_a   new_date  \
# 2022-09-06      5.490876            NaN         -2.343262      0 2022-09-06
# ...

# %%
#week days name 

df['new_date_name']=df.index.day_name()
df
# Out:
#                    a         b         c         d       new  new column  \
# 2022-09-06  0.883893  0.195865  0.357537 -2.343262 -1.985725   -1.985725
# 2022-09-07 -1.084833  0.559696  0.939469 -0.978481 -0.039012   -0.039012
# 2022-09-08  0.503097  0.406414  0.323461 -0.493411 -0.169950   -0.169950
# 2022-09-09 -0.792017 -0.842368 -1.279503  0.245715 -1.033787   -1.033787
# 2022-09-10 -0.044195  1.567633  1.051109  0.406368  1.457477    1.457477
# 2022-09-11 -0.168646 -3.189703  1.120132  1.332778  2.452910    2.452910
# 2022-09-12 -0.243339 -0.130031 -0.109017  1.556186  1.447169    1.447169
# 2022-09-13  0.128778 -2.066949 -0.885493 -1.104579 -1.990073   -1.990073
# 2022-09-14  0.932866  2.059838 -0.934938 -1.612990 -2.547928   -2.547928
# 2022-09-15  0.527070 -1.551101  0.329613 -1.136527 -0.806913   -0.806913
#
#             new_col_sq_d  new_col_log_d  new_col_dq_log_d  new_a   new_date  \
# 2022-09-06      5.490876            NaN         -2.343262      0 2022-09-06
# ...

# %%
#performing group by operation and telling count of it

df.groupby(by='new_date_name').count()
# Out:
#                a  b  c  d  new  new column  new_col_sq_d  new_col_log_d  \
# new_date_name
# Friday         1  1  1  1    1           1             1              1
# Monday         1  1  1  1    1           1             1              1
# Saturday       1  1  1  1    1           1             1              1
# Sunday         1  1  1  1    1           1             1              1
# Thursday       2  2  2  2    2           2             2              0
# Tuesday        2  2  2  2    2           2             2              0
# Wednesday      2  2  2  2    2           2             2              0
#
#                new_col_dq_log_d  new_a  new_date  day  month  year
# new_date_name
# Friday                        1      1         1    1      1     1
# Monday                        1      1         1    1      1     1
# Saturday                      1      1         1    1      1     1
# Sunday                        1      1         1    1      1     1
# ...

# %% [markdown]
# ## THANK YOU & KEEP LEARNING.
